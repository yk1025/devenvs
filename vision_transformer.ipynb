# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-kubo/devenvs/blob/keybindings/vision_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip upgrade
# !pip install -U pip
# インストール済みのバージョンではエラーが起こる。バージョンの問題らしいので最新版に上げる
# !pip install -U tensorflow-addons

# %%
# GPUが認識されていることを確認
import tensorflow as tf
tf.test.gpu_device_name()

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import (
    Dense,
    Dropout,
    LayerNormalization,
    Add,
    Activation,
    Input,
)
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical


def MultiHead_SelfAttention(inputs, embed_dim, num_heads):
    projection_dim = embed_dim // num_heads
    batch_size = K.int_shape(inputs)[0]

    query = Dense(embed_dim)(inputs)
    key = Dense(embed_dim)(inputs)
    value = Dense(embed_dim)(inputs)

    query = K.reshape(query, (batch_size, -1, num_heads, projection_dim))
    key = K.reshape(key, (batch_size, -1, num_heads, projection_dim))
    value = K.reshape(value, (batch_size, -1, num_heads, projection_dim))

    query = K.permute_dimensions(query, (0, 2, 1, 3))
    key = K.permute_dimensions(key, (0, 2, 1, 3))
    value = K.permute_dimensions(value, (0, 2, 1, 3))

    score = tf.matmul(query, key, transpose_b=True)
    score = score / K.sqrt(K.cast(projection_dim, "float32"))
    weights = Activation("softmax")(score)

    attention = tf.matmul(weights, value)
    attention = K.permute_dimensions(attention, (0, 2, 1, 3))
    attention = K.reshape(attention, (batch_size, -1, embed_dim))
    output = Dense(embed_dim)(attention)
    return output


def TransformerBlock(inputs, embed_dim, num_heads, ff_dim):
    attn_output = MultiHead_SelfAttention(inputs, embed_dim, num_heads)
    attn_output = Dropout(0.1)(attn_output)
    out1 = LayerNormalization(epsilon=1e-6)(Add()([inputs, attn_output]))
    ffn_output = Dense(ff_dim, activation="relu")(out1)
    ffn_output = Dense(embed_dim)(ffn_output)
    ffn_output = Dropout(0.1)(ffn_output)
    return LayerNormalization(epsilon=1e-6)(Add()([out1, ffn_output]))


class Add_Embedding_Layer(tf.keras.layers.Layer):
    def __init__(self, num_patches=64, d_model=64, batch_size=16):
        super(Add_Embedding_Layer, self).__init__()
        self.batch_size = batch_size
        self.patch_emb = self.add_weight(shape=[1, 1, d_model], dtype=tf.float32)
        self.pos_emb = self.add_weight(shape=[1, num_patches + 1, d_model], dtype=tf.float32)

    def call(self, input):
        patch_emb = K.repeat_elements(self.patch_emb, self.batch_size, axis=0)
        pos_emb = K.repeat_elements(self.pos_emb, self.batch_size, axis=0)
        return K.concatenate([input, patch_emb], axis=1) + pos_emb


epochs = 30
batch_size = 400


def make_ViT(img_size=32, ch_size=3, patch_size=4, batch_size=400, num_layers=4, d_model=64, num_heads=4, mlp_dim=128, num_classes=10):

    num_patches = (img_size // patch_size) ** 2
    patch_dim = ch_size * patch_size ** 2

    inputs = Input(shape=(32, 32, 3))

    x = Rescaling(1.0 / 255)(inputs)
    x = tf.nn.space_to_depth(x, patch_size)
    x = K.reshape(x, (-1, num_patches, patch_dim))
    x = Dense(d_model)(x)

    x = Add_Embedding_Layer(num_patches, d_model, batch_size)(x)
    for _ in range(num_layers):
        x = TransformerBlock(x, d_model, num_heads, mlp_dim)

    x = Dense(mlp_dim, activation=tfa.activations.gelu)(x[:, 0])
    x = Dropout(0.1)(x)
    y = Dense(num_classes, activation="softmax")(x)
    return Model(inputs=inputs, outputs=y)


model = make_ViT()
model.compile(optimizer="Adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
history = model.fit(
    x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), verbose=1,
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_addons/utils/resource_loader.py:103: UserWarning: You are currently using TensorFlow 2.3.0 and trying to load a custom op (custom_ops/activations/_activation_ops.so).
# TensorFlow Addons has compiled its custom ops against TensorFlow 2.2.0, and there are no compatibility guarantees between the two versions.
# This means that you might get segfaults when loading the custom op, or other kind of low-level errors.
#  If you do, do not file an issue on Github. This is a known limitation.
#
# It might help you to fallback to pure Python ops with TF_ADDONS_PY_OPS . To do that, see https://github.com/tensorflow/addons#gpucpu-custom-ops
#
# You can also change the TensorFlow version installed on your system. You would need a TensorFlow version equal to or above 2.2.0 and strictly below 2.3.0.
#  Note that nightly versions of TensorFlow, as well as non-pip TensorFlow like `conda install tensorflow` or compiled from source are not supported.
#
# The last solution is to find the TensorFlow Addons version that has custom ops compatible with the TensorFlow installed on your system. To do that, refer to the readme: https://github.com/tensorflow/addons
#   UserWarning,
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 32, 32, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SpaceToDepth (Tenso [(None, 8, 8, 48)]   0           rescaling[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, 64, 48)]     0           tf_op_layer_SpaceToDepth[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64, 64)       3136        tf_op_layer_Reshape[0][0]
# __________________________________________________________________________________________________
# add__embedding__layer (Add_Embe (400, 65, 64)        4224        dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (400, 65, 64)        4160        add__embedding__layer[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (400, 65, 64)        4160        add__embedding__layer[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(400, 65, 4, 16)]   0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_2 (TensorFl [(400, 65, 4, 16)]   0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose (TensorFl [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_1 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2 (Tens [(400, 4, 65, 65)]   0           tf_op_layer_Transpose[0][0]
#                                                                  tf_op_layer_Transpose_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (400, 65, 64)        4160        add__embedding__layer[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(400, 4, 65, 65)]   0           tf_op_layer_BatchMatMulV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_3 (TensorFl [(400, 65, 4, 16)]   0           dense_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (400, 4, 65, 65)     0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_2 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_1 (Te [(400, 4, 65, 16)]   0           activation[0][0]
#                                                                  tf_op_layer_Transpose_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_3 (Tensor [(400, 65, 4, 16)]   0           tf_op_layer_BatchMatMulV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_4 (TensorFl [(400, 65, 64)]      0           tf_op_layer_Transpose_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (400, 65, 64)        4160        tf_op_layer_Reshape_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (400, 65, 64)        0           dense_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (400, 65, 64)        0           add__embedding__layer[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (400, 65, 64)        128         add[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (400, 65, 128)       8320        layer_normalization[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (400, 65, 64)        8256        dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (400, 65, 64)        0           dense_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (400, 65, 64)        0           layer_normalization[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (400, 65, 64)        128         add_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (400, 65, 64)        4160        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (400, 65, 64)        4160        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_5 (TensorFl [(400, 65, 4, 16)]   0           dense_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_6 (TensorFl [(400, 65, 4, 16)]   0           dense_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_4 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_5 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_2 (Te [(400, 4, 65, 65)]   0           tf_op_layer_Transpose_4[0][0]
#                                                                  tf_op_layer_Transpose_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (400, 65, 64)        4160        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(400, 4, 65, 65)]   0           tf_op_layer_BatchMatMulV2_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_7 (TensorFl [(400, 65, 4, 16)]   0           dense_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (400, 4, 65, 65)     0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_6 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_3 (Te [(400, 4, 65, 16)]   0           activation_1[0][0]
#                                                                  tf_op_layer_Transpose_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_7 (Tensor [(400, 65, 4, 16)]   0           tf_op_layer_BatchMatMulV2_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_8 (TensorFl [(400, 65, 64)]      0           tf_op_layer_Transpose_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (400, 65, 64)        4160        tf_op_layer_Reshape_8[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (400, 65, 64)        0           dense_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (400, 65, 64)        0           layer_normalization_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (400, 65, 64)        128         add_2[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (400, 65, 128)       8320        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (400, 65, 64)        8256        dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (400, 65, 64)        0           dense_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (400, 65, 64)        0           layer_normalization_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (400, 65, 64)        128         add_3[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (400, 65, 64)        4160        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (400, 65, 64)        4160        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_9 (TensorFl [(400, 65, 4, 16)]   0           dense_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_10 (TensorF [(400, 65, 4, 16)]   0           dense_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_8 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_9 (Tensor [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_4 (Te [(400, 4, 65, 65)]   0           tf_op_layer_Transpose_8[0][0]
#                                                                  tf_op_layer_Transpose_9[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (400, 65, 64)        4160        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_2 (TensorFl [(400, 4, 65, 65)]   0           tf_op_layer_BatchMatMulV2_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_11 (TensorF [(400, 65, 4, 16)]   0           dense_15[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (400, 4, 65, 65)     0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_10 (Tenso [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_5 (Te [(400, 4, 65, 16)]   0           activation_2[0][0]
#                                                                  tf_op_layer_Transpose_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_11 (Tenso [(400, 65, 4, 16)]   0           tf_op_layer_BatchMatMulV2_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_12 (TensorF [(400, 65, 64)]      0           tf_op_layer_Transpose_11[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (400, 65, 64)        4160        tf_op_layer_Reshape_12[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (400, 65, 64)        0           dense_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (400, 65, 64)        0           layer_normalization_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (400, 65, 64)        128         add_4[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (400, 65, 128)       8320        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (400, 65, 64)        8256        dense_17[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (400, 65, 64)        0           dense_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (400, 65, 64)        0           layer_normalization_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (400, 65, 64)        128         add_5[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (400, 65, 64)        4160        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (400, 65, 64)        4160        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_13 (TensorF [(400, 65, 4, 16)]   0           dense_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_14 (TensorF [(400, 65, 4, 16)]   0           dense_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_12 (Tenso [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_13 (Tenso [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_6 (Te [(400, 4, 65, 65)]   0           tf_op_layer_Transpose_12[0][0]
#                                                                  tf_op_layer_Transpose_13[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (400, 65, 64)        4160        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_3 (TensorFl [(400, 4, 65, 65)]   0           tf_op_layer_BatchMatMulV2_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_15 (TensorF [(400, 65, 4, 16)]   0           dense_21[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (400, 4, 65, 65)     0           tf_op_layer_RealDiv_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_14 (Tenso [(400, 4, 65, 16)]   0           tf_op_layer_Reshape_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BatchMatMulV2_7 (Te [(400, 4, 65, 16)]   0           activation_3[0][0]
#                                                                  tf_op_layer_Transpose_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Transpose_15 (Tenso [(400, 65, 4, 16)]   0           tf_op_layer_BatchMatMulV2_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_16 (TensorF [(400, 65, 64)]      0           tf_op_layer_Transpose_15[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (400, 65, 64)        4160        tf_op_layer_Reshape_16[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (400, 65, 64)        0           dense_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (400, 65, 64)        0           layer_normalization_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (400, 65, 64)        128         add_6[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (400, 65, 128)       8320        layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (400, 65, 64)        8256        dense_23[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (400, 65, 64)        0           dense_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (400, 65, 64)        0           layer_normalization_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (400, 65, 64)        128         add_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(400, 64)]          0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (400, 128)           8320        tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (400, 128)           0           dense_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (400, 10)            1290        dropout_8[0][0]
# ==================================================================================================
# Total params: 150,858
# Trainable params: 150,858
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
#   2/125 [..............................] - ETA: 5s - loss: 2.4381 - accuracy: 0.1138WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0172s vs `on_train_batch_end` time: 0.0791s). Check your callbacks.
# 125/125 [==============================] - ETA: 0s - loss: 1.9951 - accuracy: 0.2507WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0033s vs `on_test_batch_end` time: 0.0175s). Check your callbacks.
# 125/125 [==============================] - 10s 81ms/step - loss: 1.9951 - accuracy: 0.2507 - val_loss: 1.7428 - val_accuracy: 0.3667
# Epoch 2/30
# 125/125 [==============================] - 10s 77ms/step - loss: 1.6734 - accuracy: 0.3838 - val_loss: 1.5037 - val_accuracy: 0.4486
# Epoch 3/30
# 125/125 [==============================] - 10s 77ms/step - loss: 1.4969 - accuracy: 0.4512 - val_loss: 1.3846 - val_accuracy: 0.4887
# Epoch 4/30
# 125/125 [==============================] - 10s 78ms/step - loss: 1.3835 - accuracy: 0.4927 - val_loss: 1.3504 - val_accuracy: 0.5061
# Epoch 5/30
# 125/125 [==============================] - 10s 79ms/step - loss: 1.3073 - accuracy: 0.5214 - val_loss: 1.2523 - val_accuracy: 0.5470
# Epoch 6/30
# 125/125 [==============================] - 10s 79ms/step - loss: 1.2430 - accuracy: 0.5484 - val_loss: 1.2091 - val_accuracy: 0.5581
# Epoch 7/30
# 125/125 [==============================] - 10s 80ms/step - loss: 1.2017 - accuracy: 0.5663 - val_loss: 1.1816 - val_accuracy: 0.5748
# Epoch 8/30
# 125/125 [==============================] - 10s 80ms/step - loss: 1.1533 - accuracy: 0.5830 - val_loss: 1.1453 - val_accuracy: 0.5873
# Epoch 9/30
# 125/125 [==============================] - 10s 81ms/step - loss: 1.1269 - accuracy: 0.5944 - val_loss: 1.1426 - val_accuracy: 0.5882
# Epoch 10/30
# 125/125 [==============================] - 10s 82ms/step - loss: 1.0915 - accuracy: 0.6063 - val_loss: 1.1071 - val_accuracy: 0.5978
# Epoch 11/30
# 125/125 [==============================] - 10s 82ms/step - loss: 1.0666 - accuracy: 0.6144 - val_loss: 1.0805 - val_accuracy: 0.6095
# Epoch 12/30
# 125/125 [==============================] - 10s 81ms/step - loss: 1.0373 - accuracy: 0.6243 - val_loss: 1.0851 - val_accuracy: 0.6088
# Epoch 13/30
# 125/125 [==============================] - 10s 82ms/step - loss: 1.0164 - accuracy: 0.6340 - val_loss: 1.0662 - val_accuracy: 0.6130
# Epoch 14/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.9898 - accuracy: 0.6431 - val_loss: 1.0817 - val_accuracy: 0.6143
# Epoch 15/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.9683 - accuracy: 0.6530 - val_loss: 1.0510 - val_accuracy: 0.6183
# Epoch 16/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.9492 - accuracy: 0.6605 - val_loss: 1.0170 - val_accuracy: 0.6351
# Epoch 17/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.9240 - accuracy: 0.6693 - val_loss: 1.0210 - val_accuracy: 0.6377
# Epoch 18/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.9110 - accuracy: 0.6724 - val_loss: 0.9881 - val_accuracy: 0.6462
# Epoch 19/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.8876 - accuracy: 0.6811 - val_loss: 1.0427 - val_accuracy: 0.6333
# Epoch 20/30
# 125/125 [==============================] - 10s 82ms/step - loss: 0.8740 - accuracy: 0.6878 - val_loss: 0.9976 - val_accuracy: 0.6493
# Epoch 21/30
# 125/125 [==============================] - 10s 82ms/step - loss: 0.8531 - accuracy: 0.6942 - val_loss: 0.9993 - val_accuracy: 0.6506
# Epoch 22/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.8357 - accuracy: 0.7010 - val_loss: 0.9997 - val_accuracy: 0.6478
# Epoch 23/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.8277 - accuracy: 0.7044 - val_loss: 0.9892 - val_accuracy: 0.6559
# Epoch 24/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.8110 - accuracy: 0.7102 - val_loss: 0.9935 - val_accuracy: 0.6522
# Epoch 25/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.8008 - accuracy: 0.7112 - val_loss: 1.0001 - val_accuracy: 0.6471
# Epoch 26/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.7823 - accuracy: 0.7211 - val_loss: 0.9954 - val_accuracy: 0.6480
# Epoch 27/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.7738 - accuracy: 0.7230 - val_loss: 1.0260 - val_accuracy: 0.6503
# Epoch 28/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.7635 - accuracy: 0.7278 - val_loss: 0.9724 - val_accuracy: 0.6588
# Epoch 29/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.7477 - accuracy: 0.7329 - val_loss: 0.9761 - val_accuracy: 0.6618
# Epoch 30/30
# 125/125 [==============================] - 10s 81ms/step - loss: 0.7401 - accuracy: 0.7339 - val_loss: 1.0235 - val_accuracy: 0.6510
